# %% [markdown]
# ## Pre-class

# %% [markdown]
# ### Task 1

# %%
f1=plot(x^2-1,(x,-1,0))
f2=plot(2*x,(x,0,1))
f3=point((1,1),pointsize=30)
f4=plot(-2*x+4,(x,1,2))
f5=line([(2,0),(3,0)])

cut1=point((0,-1),rgbcolor='white',faceted=True,pointsize=50)
cut2=point((0,0),rgbcolor='white',faceted=True,pointsize=50)
cut3=point((1,2),rgbcolor='white',faceted=True,pointsize=50)
f1+f2+f3+f4+f5+cut1+cut2+cut3

plot(a(x),(x,-1,0))
# Out:
# Graphics object consisting of 8 graphics primitives

# %% [markdown]
# b) f is continuous on {[-1, 0), (0, 1), (1, 2), [2, +inf)} and discontinuous on {0, 1}<br/>
# c) x = 0: function is not defined at this point, x = 1: limit of the function is not function value at the point

# %% [markdown]
# ### Task 4

# %%
lim(3*sin(x)^2-e^x, x=0)
# Out:
# -1

# %%
var('x,y')
g=(1-x*y)/(2*x^3+y^2)
g.limit(x=2).limit(y=1)
# Out:
# -1/17

# %%
f = piecewise( [[(-1,0),x^2-1], [(0,1),2*x], [[1,2],-2*x+4] ] )

plot(f)
# Out:
# Graphics object consisting of 1 graphics primitive
